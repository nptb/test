# %%
A1 = input("nhhập tọa độ yA: ")
A2 = input("nhập tọa độ yA: ")
B1 = input("nhập tọa độ B1 : ")
B2 = input("nhập tọa độ B2 : ")
C1 = input("nhhập tọa độ xC: ")
C2 = input("nhập tọa độ yC: ")

xAB = int(B1) - int(A1)
yAB = int(B2) - int(A2)
xBC = int(C1) - int(B1)
yBC = int(C2) - int(B2)

dAB = ((int(B1) - int(A1)) ** 2 + (int(B2) - int(A2)) ** 2)
dAC = ((int(C1) - int(A1)) ** 2 + (int(C2) - int(A2)) ** 2)
dBC = ((int(C1) - int(B1)) ** 2 + (int(C2) - int(B2)) ** 2)

VecToAB = int(xAB) / int(xBC)
VecToBC = int(yAB) / int(yBC)
if VecToAB == VecToBC:
    ABCKhongThangHang = True
    print("ABC là tam giác")
    
    if int(dAB) == (int(dAC) + int(dBC)) or int(dAC) == (int(dBC) + int(dAB)) or int(dBC) == (int(dAC) + int(dAB)):
        ABCLaTamGiacVuong = True
        print("ABC là tam giác vuông")
        
    elif int(dAB) == int(dAC) != int(dBC) or int(dAC) == int(dBC) != int(dAB) or int(dAB) == int(dBC) != int(dAC):
        ABCLaTamGiacCan = True
        print("ABC là tam giác cân")

    elif int(dAB) == int(dAC) == int(dBC):
        ABCLaTamGiacDeu = True
        print("ABC là tam giác đều")
        
    else:
        print("ABC là tam giác thường")
        
else:
    print("ABC thẳng hàng")
