# %%
import turtle

t = turtle.Turtle()
#t.speed(50)
t.pencolor('white')
screen = t.getscreen()
screen.bgcolor('black')

#thân
t.fillcolor('white')
t.begin_fill()
t.circle(-150, 360)
t.end_fill()

#đầu
t.fillcolor('white')
t.begin_fill()
t.circle(100, -360)
t.end_fill()

#mắt trái
t.penup()
t.lt(90)
t.fd(150)
t.lt(90)
t.fd(20)
t.pendown()

t.fd(30)
t.lt(90)
t.circle(15,180)

t.penup()
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(7)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.circle(5,360)
t.end_fill()

#mắt phải

t.penup()
t.bk(7)
t.rt(90)
t.bk(100)
t.pendown()

t.fd(30)
t.lt(90)
t.circle(15,180)

t.penup()
t.lt(90)
t.fd(20)
t.lt(90)
t.fd(7)
t.pendown()

t.fillcolor('black')
t.begin_fill()
t.circle(5,360)
t.end_fill()

#miệng
t.pencolor('black')
t.penup()
t.fd(70)
t.rt(90)
t.pendown()

t.fd(75)
t.lt(90)

t.circle(37,180)

t.penup()
t.lt(90)
t.fd(10)
t.rt(90)
t.pendown()

t.bk(24)

t.penup()
t.fd(24)
t.lt(90)
t.fd(10)
t.rt(90)
t.pendown()

t.bk(30)

t.penup()
t.fd(30)
t.lt(90)
t.fd(10)
t.rt(90)
t.pendown()

t.bk(35)

t.penup()
t.fd(35)
t.lt(90)
t.fd(10)
t.rt(90)
t.pendown()

t.bk(35)

t.penup()
t.fd(35)
t.lt(90)
t.fd(10)
t.rt(90)
t.pendown()

t.bk(35)

t.penup()
t.fd(35)
t.lt(90)
t.fd(10)
t.rt(90)
t.pendown()

t.bk(25)

t.penup()
t.fd(23)
t.lt(90)
t.fd(10)
t.lt(90)
t.fd(15)
t.lt(90)
t.fd(3)
t.pendown()

t.fd(65)

t.pencolor('white')
#mũi
t.penup()
t.lt(90)
t.fd(60)
t.lt(90)
t.fd(35)
t.pendown()

t.fillcolor('red')
t.begin_fill()
t.circle(7,360)
t.end_fill()

#khăn choàng
t.penup()
t.lt(90)
t.fd(130)
t.rt(90)
t.fd(65)
t.lt(180)
t.pendown()

t.pencolor('red')
t.pensize(60)
t.fd(125)

t.pensize(1)
t.lt(90)
t.fd(25)
t.rt(90)
t.fd(7)

t.pensize(30)
t.fd(5)

t.pensize(1)
t.penup()
t.bk(165)
t.rt(90)
t.fd(15)
t.pendown()
t.pencolor('black')
t.circle(10,45)
t.circle(20,50)
t.fd(165)

t.penup()
t.bk(165)
t.rt(95)
t.fd(25)
t.pendown()

t.fillcolor('red')
t.begin_fill()
t.fd(100)
t.circle(10,180)
t.fd(100)
t.penup()
t.bk(40)
t.pendown()
t.bk(30)
t.circle(-10,-180)
t.bk(70)
t.end_fill()

#hat
t.penup()
t.bk(225)
t.rt(90)
t.fd(50)
t.pendown()

t.fillcolor('brown')
t.begin_fill()
t.circle(10,180)
t.fd(170)
t.circle(10,180)
t.fd(170)
t.end_fill()

t.penup()
t.bk(10)

t.pendown()

t.fillcolor('red')
t.begin_fill()
t.circle(-10,180)
t.fd(150)
t.circle(-10,180)
t.end_fill()

t.penup()
t.fd(5)
t.rt(90)
t.fd(20)
t.pendown()

t.fillcolor('brown')
t.begin_fill()
t.fd(100)
t.circle(10,90)
t.fd(120)
t.circle(10,90)
t.fd(100)
t.end_fill()

#tay
t.penup()
t.fd(260)
t.rt(90)
t.fd(42)
t.rt(45)
t.pendown()

t.pensize(15)
t.pencolor('gray')

t.fd(100)
t.bk(30)
t.rt(40)
t.fd(25)

t.penup()
t.bk(25)
t.lt(40)
t.bk(70)
t.lt(45)

t.bk(220)
t.lt(45)
t.pendown()

t.bk(100)
t.fd(30)
t.lt(220)
t.fd(25)

t.penup()
t.fd(100)

#ngôi sao
t.pensize(0)
t.pencolor('white')

t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.fd(30)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.rt(45)
t.fd(50)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.lt(70)
t.fd(40)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.lt(70)
t.fd(35)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.rt(100)
t.fd(60)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.rt(100)
t.fd(60)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.rt(100)
t.fd(60)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()


t.penup()
t.fd(60)
t.fd(80)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.bk(300)
t.rt(40)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.fd(150)
t.rt(40)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.bk(200)
t.rt(40)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.fd(50)
t.rt(40)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.fd(100)
t.rt(40)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.bk(50)
t.rt(40)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.fd(150)
t.rt(40)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.rt(40)
t.fd(50)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.rt(40)
t.fd(50)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()


t.penup()
t.rt(50)
t.fd(50)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.rt(110)
t.fd(50)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.lt(90)
t.fd(100)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.bk(50)
t.rt(90)
t.bk(10)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.fd(45)
t.pendown()

t.pencolor('white')
t.fillcolor('white')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

t.penup()
t.lt(90)
t.fd(100)
t.pendown()

t.pencolor('yellow')
t.fillcolor('yellow')
t.begin_fill()
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.fd(20)
t.rt(144)
t.end_fill()

#house
t.pencolor('black')
t.fillcolor('red')

t.penup()
t.rt(-5)
t.fd(500)
t.rt(85)
t.fd(15)
t.pendown()
t.begin_fill()
t.bk(500)
t.lt(90)
t.fd(250)

t.penup()
t.rt(90)
t.fd(100)
t.rt(90)
t.pendown()
t.end_fill()
t.fillcolor('yellow')
t.begin_fill()
t.fd(180)
t.lt(90)
t.fd(300)
t.lt(90)
t.fd(180)
t.end_fill()

t.fillcolor('black')
t.penup()
t.bk(80)
t.rt(90)
t.pendown()
t.begin_fill()
t.bk(300)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(300)
t.end_fill()
t.penup()
t.bk(140)
t.rt(90)
t.fd(90)
t.pendown()
t.begin_fill()
t.bk(150)
t.rt(90)
t.fd(10)
t.lt(90)
t.fd(150)
t.end_fill()
t.penup()
t.bk(10)
t.lt(90)
t.fd(10)
t.pendown()

turtle.done()
